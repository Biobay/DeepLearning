# %% [markdown]
# # 🎮 StackGAN Pokemon Generator - Pipeline Completa
#
# **Questo notebook fa tutto automaticamente:**
#
# 1. ✅ Clona il repository
#
# 2. ✅ Installa le dipendenze
#
# 3. ✅ Training Stage-I (64x64)
#
# 4. ✅ Training Stage-II (215x215)
#
# 5. ✅ Generazione Pokemon da testo
#
# 6. ✅ Visualizzazione risultati
#
#
#
# **Esegui le celle in ordine e aspetta che finiscano!**

# %%
# SETUP INIZIALE - Clona repo e installa dipendenze
import os
import sys
import subprocess
import shutil

# Repository settings
GIT_REPO_URL = "https://github.com/Biobay/DeepLearning/"
BRANCH_NAME = "StackGan_finale"

# Clona o aggiorna il repository
if not os.path.exists("scripts"):
    print(f"Clonazione del branch '{BRANCH_NAME}'...")
    TEMP_DIR = "temp_clone"
    
    try:
        subprocess.run(['git', 'clone', '--branch', BRANCH_NAME, GIT_REPO_URL, TEMP_DIR], check=True)
        print("Copia dei file...")
        shutil.copytree(TEMP_DIR, ".", dirs_exist_ok=True, ignore=shutil.ignore_patterns('.git'))
        shutil.rmtree(TEMP_DIR)
        print("Repository clonato con successo!")
    except Exception as e:
        print(f"Errore durante la clonazione: {e}")
        raise
else:
    print("Repository già presente! Aggiornamento all'ultimo commit...")
    try:
        subprocess.run(['git', 'fetch', 'origin', BRANCH_NAME], check=True)
        subprocess.run(['git', 'checkout', BRANCH_NAME], check=True)
        subprocess.run(['git', 'pull', 'origin', BRANCH_NAME], check=True)
        print(" Repository aggiornato all'ultimo commit!")
    except Exception as e:
        print(f"Errore durante l'aggiornamento: {e}")
        raise

# Aggiunge al Python path
if os.getcwd() not in sys.path:
    sys.path.append(os.getcwd())
    print("Path di sistema configurato")

# Installa dipendenze
print("Installazione dipendenze...")
try:
    result = subprocess.run([sys.executable, '-m', 'pip', 'install', '-r', 'requirements.txt'], 
                          check=True, capture_output=True, text=True)
    print("Dipendenze installate con successo!")
except subprocess.CalledProcessError as e:
    print(f"Errore installazione: {e.stderr}")
    raise

print("SETUP COMPLETATO! Procedi con la cella successiva")
print("=" * 50)

# %%
# 🏋️ TRAINING STAGE-I (64x64)

try:
    from scripts.train import train
    import src.config as config
    
    print(f"Configurazione:")
    print(f"   - Epoche: {config.EPOCHS}")
    print(f"   - Device: {config.DEVICE}")
    print(f"   - Batch Size: {config.BATCH_SIZE}")
    print(f"   - Learning Rate Generatore: {config.LEARNING_RATE}")
    print(f"   - Learning Rate Discriminatore: {config.LEARNING_RATE_D}")
    print(f"   - Fine-tune BERT: {config.FINE_TUNE_ENCODER}")
    print("")
    
    print("Inizio addestramento Stage-I...")
    print("🔍 Monitoraggio Loss:")
    print("   - loss_D: Loss del Discriminatore (deve rimanere stabile, non tendere a 0)")
    print("   - loss_G: Loss totale del Generatore")
    print("   - loss_G_adv: Loss adversariale del Generatore")
    print("   - loss_G_L1: Loss di ricostruzione L1 del Generatore")
    print("")
    
    train(config)
    print("")
    print("TRAINING STAGE-I COMPLETATO!")
    print("Checkpoint salvato in: results/checkpoints/generator_s1.pth")
    print("Immagini generate in: results/generated_images/")
    print("")
    print("📊 Verifica che:")
    print("   ✅ loss_D non sia andata a 0 (grazie al learning rate ridotto)")
    print("   ✅ loss_G_adv e loss_G_L1 siano in equilibrio")
    print("   ✅ Le immagini generate migliorino progressivamente")
    
except Exception as e:
    print(f"Errore durante il training Stage-I: {e}")
    import traceback
    traceback.print_exc()
    raise

# %%
# 📊 VISUALIZZA RISULTATI STAGE-I
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import glob

print("ANALISI RISULTATI STAGE-I")
print("=" * 35)

# Visualizza loss
try:
    log_file = "results/logs/loss_log.csv"
    if os.path.exists(log_file):
        df = pd.read_csv(log_file)
        df_epoch = df.groupby('epoch').mean()
        
        plt.figure(figsize=(12, 5))
        
        plt.subplot(1, 2, 1)
        plt.plot(df_epoch.index, df_epoch['loss_d'], 'r-', label='Discriminator', linewidth=2)
        plt.plot(df_epoch.index, df_epoch['loss_g'], 'b-', label='Generator', linewidth=2)
        plt.title('Loss Stage-I', fontsize=14, fontweight='bold')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        plt.grid(True, alpha=0.3)
        
        # Mostra immagini generate
        plt.subplot(1, 2, 2)
        generated_imgs = glob.glob("results/generated_images/generated_images_epoch_*.png")
        if generated_imgs:
            latest_img = sorted(generated_imgs)[-1]
            img = Image.open(latest_img)
            plt.imshow(img)
            plt.title('Immagini Generate Stage-I', fontsize=14, fontweight='bold')
            plt.axis('off')
        
        plt.tight_layout()
        plt.show()
        
        print(f"Loss finale Discriminator: {df_epoch['loss_d'].iloc[-1]:.4f}")
        print(f"Loss finale Generator: {df_epoch['loss_g'].iloc[-1]:.4f}")
    else:
        print("File di log non trovato")
        
except Exception as e:
    print(f"Errore visualizzazione: {e}")

print("\nProcedi con Stage-II!")

# %%
# TRAINING STAGE-II (215x215)

print("AVVIO TRAINING STAGE-II (64x64 → 215x215)")

print("=" * 45)



try:

    from scripts.train_stage2 import train_stage2

    import src.config as config

    

    # Verifica che Stage-I sia completato

    checkpoint_s1 = "results/checkpoints/generator_s1.pth"

    if not os.path.exists(checkpoint_s1):

        raise FileNotFoundError(f"Checkpoint Stage-I non trovato! Esegui prima Stage-I.")

    

    print(f"Checkpoint Stage-I trovato: {checkpoint_s1}")

    print(f"Configurazione Stage-II:")

    print(f"   - Epoche: {config.EPOCHS_S2}")

    print(f"   - Learning Rate: {config.LEARNING_RATE_S2}")

    print(f"   - Lambda L1: {config.LAMBDA_L1_S2}")

    print(f"   - Output: {config.STAGE2_IMAGE_SIZE}x{config.STAGE2_IMAGE_SIZE}")

    print("")

    

    print("Inizio addestramento Stage-II...")

    train_stage2(config)

    print("")

    print("TRAINING STAGE-II COMPLETATO!")

    print(f"Checkpoint salvato in: results/checkpoints/stage2/generator_s2.pth")

    print(f"Immagini {config.STAGE2_IMAGE_SIZE}x{config.STAGE2_IMAGE_SIZE} generate in: results/generated_images/stage2/")

    

except Exception as e:

    print(f"Errore durante il training Stage-II: {e}")

    import traceback

    traceback.print_exc()

    raise

# %%
# 📊VISUALIZZA RISULTATI STAGE-II

print("ANALISI RISULTATI STAGE-II")



try:

    # Visualizza loss Stage-II
    log_file_s2 = "results/logs/loss_log_stage2.csv"
    if os.path.exists(log_file_s2):
        df_s2 = pd.read_csv(log_file_s2)
        df_epoch_s2 = df_s2.groupby('epoch').mean()
        plt.figure(figsize=(15, 5))


        # Loss Stage-II

        plt.subplot(1, 3, 1)

        plt.plot(df_epoch_s2.index, df_epoch_s2['loss_d'], 'r-', label='Discriminator', linewidth=2)

        plt.plot(df_epoch_s2.index, df_epoch_s2['loss_g'], 'b-', label='Generator Total', linewidth=2)

        plt.plot(df_epoch_s2.index, df_epoch_s2['loss_g_adv'], 'g--', label='Gen Adversarial', alpha=0.7)

        plt.plot(df_epoch_s2.index, df_epoch_s2['loss_g_l1'], 'orange', linestyle='--', label='Gen L1', alpha=0.7)

        plt.title('Loss Stage-II', fontsize=14, fontweight='bold')

        plt.xlabel('Epoch')

        plt.ylabel('Loss')

        plt.legend()

        plt.grid(True, alpha=0.3)

        

        # Immagini Stage-I (64x64)

        plt.subplot(1, 3, 2)

        stage1_imgs = glob.glob("results/generated_images/stage2/stage1_images_64_epoch_*.png")

        if stage1_imgs:
            latest_s1 = sorted(stage1_imgs)[-1]
            img_s1 = Image.open(latest_s1)
            plt.imshow(img_s1)
            plt.title('Stage-I Output (64x64)', fontsize=14, fontweight='bold')
            plt.axis('off')


        # Immagini Stage-II (215x215)

        plt.subplot(1, 3, 3)

        stage2_imgs = glob.glob("results/generated_images/stage2/stage2_images_215_epoch_*.png")

        if stage2_imgs:

            latest_s2 = sorted(stage2_imgs)[-1]

            img_s2 = Image.open(latest_s2)

            plt.imshow(img_s2)

            plt.title('Stage-II Output (215x215)', fontsize=14, fontweight='bold')

            plt.axis('off')

        

        plt.tight_layout()

        plt.show()

        

        print(f"✅Loss finale Discriminator S2: {df_epoch_s2['loss_d'].iloc[-1]:.4f}")

        print(f"Loss finale Generator S2: {df_epoch_s2['loss_g'].iloc[-1]:.4f}")

        print(f"Loss finale L1 S2: {df_epoch_s2['loss_g_l1'].iloc[-1]:.4f}")

    else:

        print("File di log Stage-II non trovato")

        

except Exception as e:

    print(f"Errore visualizzazione Stage-II: {e}")



print("\nOra puoi generare Pokemon personalizzati!")

# %%
# ?️ TRAINING STAGE-I (64x64)

try:
    from scripts.train import train
    import src.config as config
    
    print(f"Configurazione:")
    print(f"   - Epoche: {config.EPOCHS}")
    print(f"   - Device: {config.DEVICE}")
    print(f"   - Batch Size: {config.BATCH_SIZE}")
    print(f"   - Learning Rate Generatore: {config.LEARNING_RATE}")
    print(f"   - Learning Rate Discriminatore: {config.LEARNING_RATE_D}")
    print(f"   - Fine-tune BERT: {config.FINE_TUNE_ENCODER}")
    print("")
    
    print("Inizio addestramento Stage-I...")
    print("🔍 Monitoraggio Loss:")
    print("   - loss_D: Loss del Discriminatore (deve rimanere stabile, non tendere a 0)")
    print("   - loss_G: Loss totale del Generatore")
    print("   - loss_G_adv: Loss adversariale del Generatore")
    print("   - loss_G_L1: Loss di ricostruzione L1 del Generatore")
    print("")
    
    train(config)
    print("")
    print("TRAINING STAGE-I COMPLETATO!")
    print("Checkpoint salvato in: results/checkpoints/generator_s1.pth")
    print("Immagini generate in: results/generated_images/")
    print("")
    print("📊 Verifica che:")
    print("   ✅ loss_D non sia andata a 0 (grazie al learning rate ridotto)")
    print("   ✅ loss_G_adv e loss_G_L1 siano in equilibrio")
    print("   ✅ Le immagini generate migliorino progressivamente")
    
except Exception as e:
    print(f"Errore durante il training Stage-I: {e}")
    import traceback
    traceback.print_exc()
    raise

# %%
import matplotlib.pyplot as plt
import numpy as np

print("EST MULTIPLI - GENERAZIONE POKEMON DIVERSI")
print("=" * 50)

# Lista di prompt diversi da testare
test_prompts = [
    "a blue water pokemon with fins",
    "a yellow electric mouse pokemon",
    "a green grass type pokemon with leaves",
    "a purple psychic pokemon with big eyes",
    "a brown ground type pokemon"
]

try:
    # Controlla che i modelli siano già caricati dalla cella precedente
    if 'netG_s1' not in locals() or 'netG_s2' not in locals():
        print("Modelli non caricati. Esegui prima la cella di generazione!")
        raise RuntimeError("Modelli non disponibili")
    
    plt.figure(figsize=(20, 8))
    
    for i, prompt in enumerate(test_prompts):
        print(f"Generando: '{prompt}'")
        
        # Tokenizza
        tokens = tokenizer(prompt, padding='max_length', max_length=config.MAX_SEQ_LEN, 
                          truncation=True, return_tensors='pt')
        
        input_ids = tokens['input_ids'].to(device)
        attention_mask = tokens['attention_mask'].to(device)
        
        with torch.no_grad():
            # Encode text
            cls_embedding, hidden_states = text_encoder(input_ids, attention_mask)
            
            # Generate with different noise
            noise = torch.randn(1, config.Z_DIM, device=device)
            stage1_img, stage1_mu = netG_s1(cls_embedding, hidden_states, noise)
            stage2_img, _ = netG_s2(stage1_img, cls_embedding, stage1_mu)
        
        # Visualizza
        plt.subplot(1, 5, i+1)
        img_display = (stage2_img.squeeze().permute(1, 2, 0).cpu() * 0.5 + 0.5).numpy()
        img_display = np.clip(img_display, 0, 1)
        plt.imshow(img_display)
        plt.title(f"{prompt[:20]}...", fontsize=10)
        plt.axis('off')
        
        # Salva ogni immagine
        save_image(stage2_img, f"results/test_pokemon_{i+1}.png", normalize=True)
    
    plt.suptitle('Pokemon Generati da Descrizioni Diverse', fontsize=16, fontweight='bold')
    plt.tight_layout()
    plt.show()
    
    print("\n TUTTI I TEST COMPLETATI!")
    print("📁 Immagini salvate in: results/test_pokemon_*.png")
    
except Exception as e:
    print(f"Errore durante i test multipli: {e}")
    import traceback
    traceback.print_exc()

# %% [markdown]
# **Hai completato con successo il training di StackGAN!**
#
# ## Cosa abbiamo ottenuto:
# - **Stage-I trained**: Genera Pokemon 64x64 da testo
# - **Stage-II trained**: Raffina le immagini a 256x256
# - **Pipeline completa**: Text → 64x64 → 256x256
# - **Modelli salvati**: Pronti per il riuso
#
# ##  File generati:
# - `results/checkpoints/generator_s1.pth` - Modello Stage-I
# - `results/checkpoints/stage2/generator_s2.pth` - Modello Stage-II
# - `results/generated_images/` - Immagini di training
# - `results/logs/` - Log delle loss
# - `results/my_generated_pokemon.png` - La tua generazione!
#
# ## Prossimi passi:
# 1. **Modifica i prompt** nella cella di generazione
# 2. **Aumenta le epoche** per migliorare la qualità
# 3. **Crea un'interfaccia Gradio** per demo web
# 4. **Experimenta con nuovi dataset**

# %%
    def generate_pokemon(self, text_prompt, seed=None):
        """Genera un Pokemon dal testo con gestione errori robusta"""
        if not text_prompt or not text_prompt.strip():
            return None, None, "⚠️ Inserisci una descrizione del Pokemon!"
        
        try:
            # Imposta seed per riproducibilità
            if seed is not None:
                torch.manual_seed(int(seed))
                np.random.seed(int(seed))
                if torch.cuda.is_available():
                    torch.cuda.manual_seed(int(seed))
            
            print(f"🎯 Generando: '{text_prompt[:50]}...'")
            
            with torch.no_grad():
                # Codifica il testo
                try:
                    text_embeddings = self.text_encoder.encode_text([text_prompt])
                    text_embeddings = text_embeddings.to(self.device)
                    print(f"✅ Testo codificato: {text_embeddings.shape}")
                except Exception as e:
                    return None, None, f"❌ Errore codifica testo: {str(e)}"
                
                # Genera rumore
                z = torch.randn(1, config.Z_DIM, device=self.device)
                
                # Stage-I: genera 64x64
                try:
                    low_res_img = self.generator_s1(text_embeddings, z)
                    print(f"✅ Stage-I output: {low_res_img.shape}")
                except Exception as e:
                    return None, None, f"❌ Errore Stage-I: {str(e)}"
                
                # Stage-II: prova generazione alta risoluzione
                high_res_img = low_res_img  # Default: usa Stage-I
                stage2_success = False
                
                if self.s2_loaded:
                    try:
                        high_res_img = self.generator_s2(low_res_img, text_embeddings)
                        print(f"✅ Stage-II output: {high_res_img.shape}")
                        stage2_success = True
                    except Exception as e:
                        print(f"⚠️ Stage-II fallito: {str(e)[:80]}...")
                        print("🔄 Usando solo Stage-I")
                        # Ridimensiona Stage-I per compatibilità
                        import torch.nn.functional as F
                        try:
                            high_res_img = F.interpolate(low_res_img, size=(215, 215), mode='bilinear', align_corners=False)
                            print("✅ Stage-I ridimensionato a 215x215")
                        except:
                            high_res_img = low_res_img
                else:
                    print("⚠️ Stage-II non caricato - usando Stage-I ridimensionato")
                    import torch.nn.functional as F
                    try:
                        high_res_img = F.interpolate(low_res_img, size=(215, 215), mode='bilinear', align_corners=False)
                    except:
                        high_res_img = low_res_img
                
                # Converti in PIL Images
                try:
                    low_res_pil = self._tensor_to_pil(low_res_img[0])
                    high_res_pil = self._tensor_to_pil(high_res_img[0])
                except Exception as e:
                    return None, None, f"❌ Errore conversione immagine: {str(e)}"
                
                # Status info dettagliato
                status = []
                if self.s1_loaded:
                    status.append("✅ Stage-I: Modello allenato - Pokemon base 64x64")
                else:
                    status.append("⚠️ Stage-I: Pesi casuali")
                
                if self.s2_loaded and stage2_success:
                    status.append("✅ Stage-II: Modello allenato - Alta risoluzione")
                elif self.s2_loaded and not stage2_success:
                    status.append("⚠️ Stage-II: Architettura incompatibile - Usando ridimensionamento")
                else:
                    status.append("⚠️ Stage-II: Non disponibile - Usando ridimensionamento Stage-I")
                
                info = f"✅ Pokemon generato!\n"
                info += f"📝 Prompt: '{text_prompt}'\n"
                info += f"🎲 Seed: {seed if seed else 'Random'}\n\n"
                info += "🔧 **Status Modelli:**\n"
                info += "\n".join(status)
                
                if not stage2_success:
                    info += f"\n\n💡 **Nota**: Il checkpoint Stage-II ha architettura diversa.\n"
                    info += f"Per risultati migliori, ri-allena Stage-II o usa solo Stage-I."
                
                print("🎉 Generazione completata!")
                return low_res_pil, high_res_pil, info
        
        except Exception as e:
            error_msg = f"❌ Errore generale: {str(e)}"
            print(error_msg)
            import traceback
            traceback.print_exc()
            return None, None, error_msg

# %% [markdown]
# # 🌐 DEMO WEB PRONTA!
#
# ## 🔥 Per Google Colab:
# 1. **Esegui la cella sopra** - si aprirà automaticamente un link pubblico
# 2. **Copia il link** che appare (tipo: `https://xxxxx.gradio.live`)
# 3. **Condividi il link** - chiunque può usare la tua demo!
#
# ## 🎯 Come funziona:
# - La demo **carica automaticamente** i tuoi modelli allenati da `results/checkpoints/`
# - **Non serve scaricare nulla** - tutto funziona nel cloud
# - **Link pubblico temporaneo** - valido per alcune ore
#
# ## 💡 Consigli:
# - **Descrizioni dettagliate** funzionano meglio
# - **Usa i seed** per risultati riproducibili
# - **Prova gli esempi** per vedere subito i risultati
#
# **🚀 I tuoi modelli StackGAN sono ora online e pronti per essere usati da chiunque!**

# %%
# 🔧 DEMO GRADIO CORRETTA - VERSIONE COMPATIBILE
print("🔧 DEMO GRADIO - VERSIONE CORRETTA")
print("=" * 40)

import os
import sys
import subprocess
import torch
import numpy as np
from PIL import Image
import warnings
warnings.filterwarnings('ignore')

# Installa Gradio
try:
    import gradio as gr
    print("✅ Gradio disponibile")
except ImportError:
    print("📦 Installazione Gradio...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "gradio"])
    import gradio as gr
    print("✅ Gradio installato!")

# Import CORRETTI - usa decoder.py (con img_encoder)
try:
    from src.models.encoder import TextEncoder
    from src.models.decoder import GeneratorS1, GeneratorS2  # ✅ DECODER.PY
    import src.config as config
    print("✅ Moduli StackGAN importati (versione CORRETTA)")
except ImportError as e:
    print(f"❌ Errore import: {e}")
    sys.exit(1)

class StackGANDemoFixed:
    def __init__(self):
        self.device = torch.device(config.DEVICE)
        print(f"🚀 Inizializzazione demo CORRETTA su: {self.device}")
        
        # Modelli
        try:
            self.text_encoder = TextEncoder(model_name=config.ENCODER_MODEL_NAME, fine_tune=False).to(self.device)
            self.generator_s1 = GeneratorS1(config=config).to(self.device)
            self.generator_s2 = GeneratorS2(config=config).to(self.device)  # ✅ CON img_encoder
            print("✅ Modelli inizializzati correttamente")
        except Exception as e:
            print(f"❌ Errore inizializzazione: {e}")
            raise
        
        # Carica checkpoint
        self.s1_loaded = False
        self.s2_loaded = False
        self._load_checkpoints_fixed()
        
        # Eval mode
        self.text_encoder.eval()
        self.generator_s1.eval()
        self.generator_s2.eval()
        
        print("✅ Demo CORRETTA inizializzata!")
    
    def _load_checkpoints_fixed(self):
        """Carica i checkpoint con la versione corretta del modello"""
        print("🔍 Caricamento checkpoint con modello CORRETTO...")
        
        # Stage-I
        s1_path = "results/checkpoints/generator_s1.pth"
        if os.path.exists(s1_path):
            try:
                self.generator_s1.load_state_dict(torch.load(s1_path, map_location=self.device))
                print(f"✅ Stage-I caricato: {s1_path}")
                self.s1_loaded = True
            except Exception as e:
                print(f"❌ Errore Stage-I: {str(e)[:80]}...")
        else:
            print("⚠️ Checkpoint Stage-I non trovato")
        
        # Stage-II - ora dovrebbe funzionare!
        s2_path = "results/checkpoints/stage2/generator_s2.pth"
        if os.path.exists(s2_path):
            try:
                self.generator_s2.load_state_dict(torch.load(s2_path, map_location=self.device))
                print(f"✅ Stage-II caricato CORRETTAMENTE: {s2_path}")
                self.s2_loaded = True
            except Exception as e:
                print(f"❌ Errore Stage-II: {str(e)[:80]}...")
                # Prova caricamento parziale se necessario
                try:
                    checkpoint = torch.load(s2_path, map_location=self.device)
                    self.generator_s2.load_state_dict(checkpoint, strict=False)
                    print("✅ Stage-II caricato parzialmente")
                    self.s2_loaded = True
                except:
                    print("❌ Stage-II completamente incompatibile")
        else:
            print("⚠️ Checkpoint Stage-II non trovato")
    
    def generate_pokemon_fixed(self, text_prompt, seed=None):
        """Genera Pokemon con la VERSIONE CORRETTA dei modelli"""
        if not text_prompt or not text_prompt.strip():
            return None, None, "⚠️ Inserisci una descrizione!"
        
        try:
            # Seed
            if seed is not None:
                torch.manual_seed(int(seed))
                np.random.seed(int(seed))
                if torch.cuda.is_available():
                    torch.cuda.manual_seed(int(seed))
            
            print(f"🎯 Generando: '{text_prompt[:50]}...'")
            
            with torch.no_grad():
                # 1. Codifica testo - versione COMPLETA come nel training
                try:
                    from transformers import AutoTokenizer
                    tokenizer = AutoTokenizer.from_pretrained(config.ENCODER_MODEL_NAME)
                    
                    tokens = tokenizer(text_prompt, padding='max_length', 
                                     max_length=config.MAX_TEXT_LENGTH, 
                                     truncation=True, return_tensors='pt')
                    
                    input_ids = tokens['input_ids'].to(self.device)
                    attention_mask = tokens['attention_mask'].to(self.device)
                    
                    # Ottieni BOTH cls_embedding e hidden_states
                    cls_embedding, hidden_states = self.text_encoder(input_ids, attention_mask)
                    print(f"✅ Testo codificato: cls={cls_embedding.shape}, hidden={hidden_states.shape}")
                    
                except Exception as e:
                    return None, None, f"❌ Errore codifica testo: {str(e)}"
                
                # 2. Stage-I: genera 64x64 CON mu parameter
                try:
                    noise = torch.randn(1, config.Z_DIM, device=self.device)
                    # ✅ USA LA FIRMA CORRETTA (3 parametri)
                    stage1_img, stage1_mu = self.generator_s1(cls_embedding, hidden_states, noise)
                    print(f"✅ Stage-I output: img={stage1_img.shape}, mu={stage1_mu.shape}")
                except Exception as e:
                    return None, None, f"❌ Errore Stage-I: {str(e)}"
                
                # 3. Stage-II: usa la FIRMA CORRETTA (3 parametri)
                stage2_img = stage1_img  # Default
                stage2_success = False
                
                if self.s2_loaded:
                    try:
                        # ✅ USA LA FIRMA CORRETTA (3 parametri)
                        stage2_img, stage2_mu = self.generator_s2(stage1_img, cls_embedding, stage1_mu)
                        print(f"✅ Stage-II output: {stage2_img.shape}")
                        stage2_success = True
                    except Exception as e:
                        print(f"⚠️ Stage-II fallito: {str(e)[:80]}...")
                        # Fallback: ridimensiona Stage-I
                        import torch.nn.functional as F
                        stage2_img = F.interpolate(stage1_img, size=(215, 215), mode='bilinear', align_corners=False)
                        print("🔄 Usando Stage-I ridimensionato")
                else:
                    print("⚠️ Stage-II non caricato")
                    import torch.nn.functional as F
                    stage2_img = F.interpolate(stage1_img, size=(215, 215), mode='bilinear', align_corners=False)
                
                # 4. Converti in PIL
                try:
                    stage1_pil = self._tensor_to_pil(stage1_img[0])
                    stage2_pil = self._tensor_to_pil(stage2_img[0])
                except Exception as e:
                    return None, None, f"❌ Errore conversione: {str(e)}"
                
                # 5. Status info
                status = []
                if self.s1_loaded:
                    status.append("✅ Stage-I: Modello allenato (64x64)")
                else:
                    status.append("⚠️ Stage-I: Pesi casuali")
                
                if self.s2_loaded and stage2_success:
                    status.append("✅ Stage-II: Modello allenato (215x215)")
                elif self.s2_loaded:
                    status.append("⚠️ Stage-II: Parzialmente funzionante")
                else:
                    status.append("❌ Stage-II: Non caricato")
                
                info = f"✅ Pokemon generato!\n"
                info += f"📝 Prompt: '{text_prompt}'\n" 
                info += f"🎲 Seed: {seed if seed else 'Random'}\n\n"
                info += "🔧 **Status Modelli:**\n"
                info += "\n".join(status)
                
                if stage2_success:
                    info += f"\n\n🎉 **Perfetto!** Entrambi i modelli funzionano!"
                else:
                    info += f"\n\n💡 **Stage-I funziona, Stage-II in fallback mode**"
                
                print("🎉 Generazione completata!")
                return stage1_pil, stage2_pil, info
        
        except Exception as e:
            error_msg = f"❌ Errore: {str(e)}"
            print(error_msg)
            import traceback
            traceback.print_exc()
            return None, None, error_msg
    
    def _tensor_to_pil(self, tensor):
        """Converte tensore in PIL"""
        try:
            tensor = (tensor + 1.0) / 2.0
            tensor = torch.clamp(tensor, 0, 1)
            
            if tensor.dim() == 3:
                np_img = tensor.cpu().numpy()
                np_img = np.transpose(np_img, (1, 2, 0))
            else:
                raise ValueError(f"Dimensioni tensor: {tensor.shape}")
            
            np_img = (np_img * 255).astype(np.uint8)
            
            if np_img.shape[2] == 3:
                return Image.fromarray(np_img, 'RGB')
            else:
                raise ValueError(f"Canali: {np_img.shape[2]}")
        except Exception as e:
            print(f"❌ Errore conversione: {e}")
            placeholder = np.zeros((64, 64, 3), dtype=np.uint8)
            return Image.fromarray(placeholder, 'RGB')

# Inizializza demo CORRETTA
print("🔧 Inizializzazione demo CORRETTA...")
try:
    demo_fixed = StackGANDemoFixed()
    demo_ready = True
    print("✅ Demo CORRETTA inizializzata!")
except Exception as e:
    print(f"❌ Errore demo: {e}")
    demo_ready = False
    # Dummy per evitare errori
    class DummyDemo:
        def __init__(self):
            self.s1_loaded = False
            self.s2_loaded = False
        def generate_pokemon_fixed(self, text, seed):
            return None, None, "❌ Demo non funziona"
    demo_fixed = DummyDemo()

# Esempi
examples = [
    ["a red fire dragon pokemon with wings", 42],
    ["a blue water pokemon with fins", 123],
    ["a yellow electric mouse pokemon", 456],
    ["a green grass pokemon with leaves", 789],
    ["a purple psychic cat pokemon", 101]
]

# Interfaccia Gradio CORRETTA
print("🌐 Creazione interfaccia Gradio CORRETTA...")

with gr.Blocks(title="🔧 StackGAN Fixed Demo", theme=gr.themes.Soft()) as interface_fixed:
    
    gr.Markdown(f"""
    # 🔧 StackGAN Pokemon Generator - VERSIONE CORRETTA
    
    **Risolve i problemi di compatibilità Stage-II!**
    
    **Status Sistema CORRETTO:**
    - 🔧 Usa modello da `decoder.py` (con img_encoder)
    - 🎯 Stage-I: {'✅ Funzionante' if demo_ready and demo_fixed.s1_loaded else '⚠️ Problema'}
    - 🚀 Stage-II: {'✅ Dovrebbe funzionare!' if demo_ready and demo_fixed.s2_loaded else '❌ Checkpoint mancante'}
    
    **✅ Questa versione:**
    - Usa l'import corretto (`decoder.py`)
    - Chiama i modelli con i parametri giusti
    - Gestisce `stage1_mu` correttamente
    - Dovrebbe caricare Stage-II senza errori!
    """)
    
    with gr.Row():
        with gr.Column(scale=1):
            text_input = gr.Textbox(
                label="📝 Descrizione Pokemon",
                placeholder="Descrivi il Pokemon...",
                lines=3,
                value="a red fire dragon pokemon with wings"
            )
            
            seed_input = gr.Number(
                label="🎲 Seed",
                value=42,
                precision=0
            )
            
            generate_btn = gr.Button("🔧 Genera Pokemon (VERSIONE CORRETTA)!", variant="primary", size="lg")
        
        with gr.Column(scale=2):
            with gr.Row():
                stage1_output = gr.Image(label="🎯 Stage-I (64x64)", height=250)
                stage2_output = gr.Image(label="🚀 Stage-II (215x215)", height=250)
            
            info_output = gr.Markdown("👆 Prova la versione CORRETTA!")
    
    # Collega evento
    generate_btn.click(
        demo_fixed.generate_pokemon_fixed,
        inputs=[text_input, seed_input],
        outputs=[stage1_output, stage2_output, info_output]
    )
    
    # Esempi
    gr.Examples(
        examples=examples,
        inputs=[text_input, seed_input],
        label="🎯 Esempi - Prova questi!"
    )

print("✅ Interfaccia CORRETTA creata!")

# Avvia demo
print("🚀 Avvio demo CORRETTA...")
try:
    interface_fixed.launch(
        share=True,
        debug=True,
        show_error=True,
        height=700,
        server_name="0.0.0.0",
        server_port=7862,
        quiet=False
    )
    print("✅ Demo CORRETTA avviata!")
except Exception as e:
    print(f"⚠️ Tentativo locale...")
    try:
        interface_fixed.launch(
            share=False,
            debug=True,
            show_error=True,
            server_port=7863,
            quiet=False
        )
    except Exception as e2:
        print(f"❌ Errore avvio: {e2}")

print("\n🎉 QUESTA VERSIONE DOVREBBE RISOLVERE TUTTI I PROBLEMI STAGE-II!")
print("Se Stage-II ora si carica senza errori 'img_encoder', il problema è risolto!")

# %%
# 🔧 FIX FRPC PER LINK PUBBLICO - VERSIONE CORRETTA
print("🔧 Download automatico frpc per link pubblico...")

import os
import urllib.request
import stat
from pathlib import Path

def setup_frpc_fixed():
    """Scarica e configura frpc nel percorso CORRETTO"""
    try:
        # ✅ Percorso CORRETTO come richiesto dall'errore
        frpc_dir = Path("/root/.cache/huggingface/gradio/frpc")
        frpc_dir.mkdir(parents=True, exist_ok=True)
        
        # ✅ Nome file CORRETTO
        frpc_file = frpc_dir / "frpc_linux_amd64_v0.3"
        
        if frpc_file.exists():
            print("✅ frpc già presente!")
            return True
        
        print("📥 Scaricamento frpc dal CDN ufficiale...")
        
        # ✅ URL ufficiale Hugging Face
        url = "https://cdn-media.huggingface.co/frpc-gradio-0.3/frpc_linux_amd64"
        
        # Download diretto
        print(f"📍 Scaricando da: {url}")
        print(f"📍 Salvando in: {frpc_file}")
        
        urllib.request.urlretrieve(url, str(frpc_file))
        
        # Rendi eseguibile
        st = os.stat(frpc_file)
        os.chmod(frpc_file, st.st_mode | stat.S_IEXEC)
        
        # Verifica dimensioni
        size = os.path.getsize(frpc_file)
        print(f"✅ frpc scaricato! Dimensione: {size / 1024 / 1024:.1f} MB")
        print(f"✅ Installato in: {frpc_file}")
        
        return True
        
    except Exception as e:
        print(f"❌ Errore download frpc: {e}")
        print("💡 Prova la Soluzione 2 (ngrok) come alternativa")
        return False

# Esegui setup
print("🚀 Configurazione frpc...")
if setup_frpc_fixed():
    print("\n🎉 FRPC CONFIGURATO CORRETTAMENTE!")
    print("Ora riavvia la demo (cella precedente) per ottenere il link pubblico!")
    print("🔗 Dovrebbe apparire: https://xxxxx.gradio.live")
else:
    print("\n⚠️ frpc non installato - prova l'alternativa ngrok sotto")

# %%
# 🌐 ALTERNATIVA: NGROK per link pubblico
print("🌐 Setup ngrok come alternativa a frpc...")

import subprocess
import sys
import time

def setup_ngrok():
    """Installa e configura ngrok per tunnel pubblico"""
    try:
        # Installa pyngrok
        print("📦 Installazione pyngrok...")
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'pyngrok'])
        
        from pyngrok import ngrok
        
        # Crea tunnel per la porta della demo (7862)
        print("🔗 Creazione tunnel ngrok...")
        public_url = ngrok.connect(7862)
        
        print(f"\n🎉 TUNNEL NGROK ATTIVO!")
        print(f"🔗 Link pubblico: {public_url}")
        print(f"📱 Condividi questo link con chiunque!")
        print(f"⏰ Il tunnel resta attivo finché questa cella gira")
        
        return str(public_url)
        
    except Exception as e:
        print(f"❌ Errore ngrok: {e}")
        return None

# Esegui setup (solo se frpc non funziona)
try:
    # Prova prima se esiste frpc
    frpc_path = "/root/.cache/huggingface/gradio/frpc/frpc_linux_amd64_v0.3"
    if not os.path.exists(frpc_path):
        print("frpc non trovato, provo ngrok...")
        tunnel_url = setup_ngrok()
        if tunnel_url:
            print(f"\n✅ USA QUESTO LINK: {tunnel_url}")
    else:
        print("✅ frpc trovato, usa la demo normale!")
        
except Exception as e:
    print(f"⚠️ Entrambe le soluzioni hanno problemi: {e}")
    print("💡 Prova la Soluzione 3 (locale + port forwarding)")

# %% [markdown]
# # 📱 **Soluzione 3: Accesso Locale + Port Forwarding**
#
# Se le soluzioni automatiche non funzionano, puoi usare la demo localmente:
#
# ## 🔧 **Setup Gradio Locale:**
#
# 1. **La demo è già attiva** su: `http://0.0.0.0:7862`
# 2. **Accedi da qualsiasi dispositivo** nella stessa rete con: `http://[TUO-IP]:7862`
# 3. **Per trovare il tuo IP:**
#    ```bash
#    # Su Mac/Linux
#    ifconfig | grep "inet " | grep -v 127.0.0.1
#
#    # Su Windows
#    ipconfig
#    ```
#
# ## 🌐 **Per Accesso Pubblico:**
#
# ### **Opzione A: SSH Tunnel (se hai server)**
# ```bash
# ssh -R 80:localhost:7862 serveo.net
# # Ti darà un link pubblico tipo: https://xyz.serveo.net
# ```
#
# ### **Opzione B: Cloudflare Tunnel (gratuito)**
# ```bash
# # Installa cloudflared
# # Poi: cloudflared tunnel --url http://localhost:7862
# ```
#
# ### **Opzione C: Servizi Online**
# - **Localtonet**: https://localtonet.com
# - **PageKite**: https://pagekite.net
# - **Serveo**: https://serveo.net
#
# ## ✅ **La Demo Funziona Perfettamente!**
# - ✅ Stage-I: Caricato correttamente
# - ✅ Stage-II: Caricato correttamente
# - ✅ Interfaccia: Funzionante
# - ❓ Solo il link pubblico automatico ha problemi
#
# **💡 Usa la Soluzione 1 (frpc fix) - dovrebbe risolvere tutto!**

# %% [markdown]
# # 🎯 **SOMMARIO: Come Rendere Pubblica la Demo**
#
# ## 🚀 **Tre Soluzioni Ordinate per Facilità:**
#
# ### **1️⃣ SOLUZIONE RACCOMANDATA: FIX FRPC**
# ```python
# # Esegui la cella sopra con la funzione setup_frpc()
# # Riavvia poi la demo - dovrebbe generare link pubblico
# ```
# **Pro:** ✅ Soluzione automatica, ✅ Link https://xyz.gradio.live
# **Contro:** ❓ Potrebbe servire riavvio
#
# ---
#
# ### **2️⃣ ALTERNATIVA: NGROK**
# ```python
# # Esegui la cella ngrok sopra
# # Ottieni link tipo: https://abc123.ngrok.io
# ```
# **Pro:** ✅ Sempre funziona, ✅ Link stabile
# **Contro:** ⚠️ Richiede account gratuito
#
# ---
#
# ### **3️⃣ BACKUP: ACCESSO LOCALE**
# ```
# http://[TUO-IP]:7862  # Dalla stessa rete
# ```
# **Pro:** ✅ Sempre disponibile
# **Contro:** ❌ Solo rete locale
#
# ---
#
# ## 📋 **PROSSIMI PASSI:**
#
# 1. **Prova prima la Soluzione 1** (frpc fix)
# 2. **Se non funziona, usa ngrok** (Soluzione 2)
# 3. **Altrimenti accesso locale** (Soluzione 3)
#
# ### 🎮 **La Demo StackGAN Pokémon è PRONTA!**
# - 🔥 **Stage-I**: Genera immagini 64x64
# - 🔥 **Stage-II**: Migliora a 215x215
# - 🎨 **Testo**: "Electric flying pokemon" → 🦋⚡
# - 🌟 **Interfaccia**: Completamente funzionante
#
# **🎊 CONGRATULAZIONI! Il tuo StackGAN deployment è completo!**

# %%
# 📥 DOWNLOAD CHECKPOINT DA JUPYTER NOTEBOOK
print("📥 Download checkpoint per Hugging Face Deploy")
print("=" * 50)

import os
import zipfile
from google.colab import files
import shutil

def download_checkpoints():
    """Scarica i checkpoint dal notebook"""
    try:
        # Verifica che i checkpoint esistano
        checkpoint_paths = [
            "results/checkpoints/generator_s1.pth",
            "results/checkpoints/stage2/generator_s2.pth"
        ]
        
        existing_checkpoints = []
        for path in checkpoint_paths:
            if os.path.exists(path):
                existing_checkpoints.append(path)
                size_mb = os.path.getsize(path) / (1024 * 1024)
                print(f"✅ Trovato: {path} ({size_mb:.1f} MB)")
            else:
                print(f"❌ Mancante: {path}")
        
        if not existing_checkpoints:
            print("❌ Nessun checkpoint trovato! Esegui prima il training.")
            return False
        
        # Crea cartella temporanea per il download
        download_dir = "checkpoint_download"
        if os.path.exists(download_dir):
            shutil.rmtree(download_dir)
        
        os.makedirs(f"{download_dir}/checkpoints", exist_ok=True)
        os.makedirs(f"{download_dir}/checkpoints/stage2", exist_ok=True)
        
        # Copia i checkpoint nella cartella download
        for checkpoint in existing_checkpoints:
            if "stage2" in checkpoint:
                dest = f"{download_dir}/checkpoints/stage2/generator_s2.pth"
            else:
                dest = f"{download_dir}/checkpoints/generator_s1.pth"
            
            shutil.copy2(checkpoint, dest)
            print(f"📁 Copiato: {checkpoint} → {dest}")
        
        # Crea zip per download
        zip_name = "stackgan_checkpoints.zip"
        with zipfile.ZipFile(zip_name, 'w', zipfile.ZIP_DEFLATED) as zipf:
            for root, dirs, files in os.walk(download_dir):
                for file in files:
                    file_path = os.path.join(root, file)
                    arcname = os.path.relpath(file_path, download_dir)
                    zipf.write(file_path, arcname)
                    print(f"📦 Aggiunto al zip: {arcname}")
        
        zip_size = os.path.getsize(zip_name) / (1024 * 1024)
        print(f"\n✅ Zip creato: {zip_name} ({zip_size:.1f} MB)")
        
        # Download automatico
        print("🔽 Avvio download...")
        files.download(zip_name)
        
        # Cleanup
        shutil.rmtree(download_dir)
        os.remove(zip_name)
        
        print("\n🎉 DOWNLOAD COMPLETATO!")
        print("📁 File scaricato: stackgan_checkpoints.zip")
        print("\n📋 PROSSIMI PASSI:")
        print("1. Estrai lo zip sul tuo computer")
        print("2. Carica i file .pth su Hugging Face Spaces")
        print("3. La struttura deve essere:")
        print("   📁 checkpoints/")
        print("   ├── generator_s1.pth")
        print("   └── stage2/")
        print("       └── generator_s2.pth")
        
        return True
        
    except Exception as e:
        print(f"❌ Errore download: {e}")
        return False

# Esegui download
download_checkpoints()

# %% [markdown]
# # 🚀 3 MODI PER RENDERE LA DEMO PUBBLICA
#
# ## 🔧 Opzione 1: Fix frpc (veloce)
# 1. **Esegui la cella sopra** - scarica frpc automaticamente
# 2. **Riavvia la demo** - ora dovrebbe creare il link pubblico
# 3. **Condividi il link** - tipo `https://xxxxx.gradio.live`
#
# ## 🚇 Opzione 2: ngrok (alternativa)
# 1. **Esegui setup_ngrok()** dalla cella sopra
# 2. **Poi esegui**: `launch_with_ngrok()`
# 3. **Usa il link ngrok** che appare
#
# ## ☁️ Opzione 3: Hugging Face Spaces (permanente)
# **La migliore per uso a lungo termine!**
#
# Hai già tutto pronto in `huggingface_deploy/`:
# - ✅ `app.py` - Demo con frpc automatico
# - ✅ `requirements.txt` - Dipendenze
# - ✅ `README.md` - Documentazione
#
# **Per deployare:**
# 1. Vai su [huggingface.co/spaces/Biobay88/deep](https://huggingface.co/spaces/Biobay88/deep)
# 2. Clicca "Files" → "Upload files"
# 3. Carica tutti i file da `huggingface_deploy/`
# 4. **Aspetta il build** (2-3 minuti)
# 5. **La tua demo sarà online 24/7!**
#
# ---
#
# ## 💡 Raccomandazione:
# - **Per test rapidi**: Usa Opzione 1 o 2
# - **Per condivisione permanente**: Usa Opzione 3 (Hugging Face)
#
# **🎯 Quale preferisci?**

# %%
# 🎯 ANALISI AUTOMATICA DEI MIGLIORI CHECKPOINT
print("🎯 Trova automaticamente i checkpoint migliori")
print("=" * 50)

import pandas as pd
import matplotlib.pyplot as plt
import glob

def find_best_checkpoints():
    """Analizza le loss e trova i checkpoint migliori"""
    
    best_s1_epoch = None
    best_s2_epoch = None
    
    # ===== STAGE-I ANALYSIS =====
    print("🔍 ANALISI STAGE-I:")
    s1_log = "results/logs/loss_log.csv"
    
    if os.path.exists(s1_log):
        df1 = pd.read_csv(s1_log)
        df1_epoch = df1.groupby('epoch').mean()
        
        # Criteri per Stage-I: loss bilanciate e stabili
        df1_epoch['loss_balance'] = abs(df1_epoch['loss_d'] - df1_epoch['loss_g'])
        df1_epoch['loss_avg'] = (df1_epoch['loss_d'] + df1_epoch['loss_g']) / 2
        
        # Penalizza loss troppo alte o troppo basse
        valid_epochs = df1_epoch[
            (df1_epoch['loss_avg'] > 0.2) & 
            (df1_epoch['loss_avg'] < 5.0) &
            (df1_epoch['loss_balance'] < 2.0)
        ]
        
        if not valid_epochs.empty:
            # Scegli epoca con migliore bilanciamento
            best_s1_epoch = valid_epochs['loss_balance'].idxmin()
            
            print(f"✅ Stage-I migliore: EPOCA {best_s1_epoch}")
            print(f"   Loss D: {df1_epoch.loc[best_s1_epoch, 'loss_d']:.4f}")
            print(f"   Loss G: {df1_epoch.loc[best_s1_epoch, 'loss_g']:.4f}")
            print(f"   Bilanciamento: {df1_epoch.loc[best_s1_epoch, 'loss_balance']:.4f}")
        else:
            print("❌ Nessuna epoca Stage-I soddisfa i criteri")
    else:
        print("❌ File loss Stage-I non trovato")
    
    print()
    
    # ===== STAGE-II ANALYSIS =====
    print("🚀 ANALISI STAGE-II:")
    s2_log = "results/logs/loss_log_stage2.csv"
    
    if os.path.exists(s2_log):
        df2 = pd.read_csv(s2_log)
        df2_epoch = df2.groupby('epoch').mean()
        
        # Criteri per Stage-II: L1 loss bassa + loss bilanciate
        valid_epochs_s2 = df2_epoch[
            (df2_epoch['loss_g_l1'] < 0.5) &  # L1 loss non troppo alta
            (df2_epoch['loss_d'] > 0.1) &     # Discriminator non troppo forte
            (df2_epoch['loss_d'] < 3.0) &     # Discriminator non troppo debole
            (df2_epoch['loss_g'] < 10.0)      # Generator non esploso
        ]
        
        if not valid_epochs_s2.empty:
            # Score: privilegia L1 loss bassa
            valid_epochs_s2['score'] = (
                1.0 / (valid_epochs_s2['loss_g_l1'] + 0.01) +  # L1 bassa = meglio
                1.0 / (abs(valid_epochs_s2['loss_d'] - 0.5) + 0.01)  # D loss ~0.5 = meglio
            )
            
            best_s2_epoch = valid_epochs_s2['score'].idxmax()
            
            print(f"✅ Stage-II migliore: EPOCA {best_s2_epoch}")
            print(f"   Loss D: {df2_epoch.loc[best_s2_epoch, 'loss_d']:.4f}")
            print(f"   Loss G: {df2_epoch.loc[best_s2_epoch, 'loss_g']:.4f}")
            print(f"   Loss L1: {df2_epoch.loc[best_s2_epoch, 'loss_g_l1']:.4f}")
            print(f"   Score: {valid_epochs_s2.loc[best_s2_epoch, 'score']:.2f}")
        else:
            print("❌ Nessuna epoca Stage-II soddisfa i criteri")
    else:
        print("❌ File loss Stage-II non trovato")
    
    print()
    
    # ===== RICERCA CHECKPOINT FILES =====
    print("📁 RICERCA CHECKPOINT DISPONIBILI:")
    
    # Stage-I checkpoints
    s1_checkpoints = glob.glob("results/checkpoints/generator_s1_epoch_*.pth")
    s1_checkpoints += glob.glob("results/checkpoints/generator_s1.pth")
    
    if s1_checkpoints:
        print(f"📄 Stage-I trovati: {len(s1_checkpoints)} checkpoint")
        for ckpt in sorted(s1_checkpoints)[:5]:  # Mostra primi 5
            size_mb = os.path.getsize(ckpt) / (1024 * 1024)
            epoch = "finale" if "epoch" not in ckpt else ckpt.split("epoch_")[1].split(".")[0]
            print(f"   • Epoca {epoch}: {os.path.basename(ckpt)} ({size_mb:.1f} MB)")
    else:
        print("❌ Nessun checkpoint Stage-I trovato")
    
    # Stage-II checkpoints  
    s2_checkpoints = glob.glob("results/checkpoints/stage2/generator_s2_epoch_*.pth")
    s2_checkpoints += glob.glob("results/checkpoints/stage2/generator_s2.pth")
    
    if s2_checkpoints:
        print(f"📄 Stage-II trovati: {len(s2_checkpoints)} checkpoint")
        for ckpt in sorted(s2_checkpoints)[:5]:  # Mostra primi 5
            size_mb = os.path.getsize(ckpt) / (1024 * 1024)
            epoch = "finale" if "epoch" not in ckpt else ckpt.split("epoch_")[1].split(".")[0]
            print(f"   • Epoca {epoch}: {os.path.basename(ckpt)} ({size_mb:.1f} MB)")
    else:
        print("❌ Nessun checkpoint Stage-II trovato")
    
    print()
    
    # ===== RACCOMANDAZIONI =====
    print("🎯 RACCOMANDAZIONI FINALI:")
    
    if best_s1_epoch is not None:
        s1_recommended = f"results/checkpoints/generator_s1_epoch_{best_s1_epoch}.pth"
        if os.path.exists(s1_recommended):
            print(f"✅ STAGE-I: Usa {s1_recommended}")
        else:
            print(f"⚠️ STAGE-I: Epoca {best_s1_epoch} raccomandata ma file non trovato")
            print("   Usa il checkpoint disponibile più vicino")
    else:
        print("⚠️ STAGE-I: Analizza manualmente le loss, prendi epoca 15-25")
    
    if best_s2_epoch is not None:
        s2_recommended = f"results/checkpoints/stage2/generator_s2_epoch_{best_s2_epoch}.pth"
        if os.path.exists(s2_recommended):
            print(f"✅ STAGE-II: Usa {s2_recommended}")
        else:
            print(f"⚠️ STAGE-II: Epoca {best_s2_epoch} raccomandata ma file non trovato")
            print("   Usa il checkpoint disponibile più vicino")
    else:
        print("⚠️ STAGE-II: Analizza manualmente le loss, prendi epoca 10-20")
    
    print("\n💡 RICORDA: Rinomina i file scelti in:")
    print("   • generator_s1.pth (per Stage-I)")
    print("   • generator_s2.pth (per Stage-II)")
    print("\n🎯 Questi sono i 2 UNICI file da caricare su Hugging Face!")
    
    return best_s1_epoch, best_s2_epoch

# Esegui analisi
best_epochs = find_best_checkpoints()

# %%
# 📁 PREPARA CHECKPOINT per HUGGING FACE (Struttura Corretta)
print("📁 Preparazione checkpoint con struttura Hugging Face")
print("=" * 55)

import shutil

def prepare_checkpoints_for_hf():
    """Prepara i checkpoint con la struttura corretta per Hugging Face Spaces"""
    try:
        # Cartella di destinazione per HF
        hf_checkpoint_dir = "huggingface_deploy/checkpoints"
        
        # Crea le cartelle se non esistono
        os.makedirs(hf_checkpoint_dir, exist_ok=True)
        os.makedirs(f"{hf_checkpoint_dir}/stage2", exist_ok=True)
        
        print(f"📁 Creata struttura in: {hf_checkpoint_dir}")
        
        # ===== TROVA I MIGLIORI CHECKPOINT =====
        best_s1_path = None
        best_s2_path = None
        
        # Cerca checkpoint Stage-I
        s1_candidates = [
            "results/checkpoints/generator_s1.pth",  # Finale
        ]
        
        # Aggiungi checkpoint per epoca se esistono
        import glob
        s1_candidates.extend(glob.glob("results/checkpoints/generator_s1_epoch_*.pth"))
        
        for path in s1_candidates:
            if os.path.exists(path):
                best_s1_path = path
                break
        
        # Cerca checkpoint Stage-II
        s2_candidates = [
            "results/checkpoints/stage2/generator_s2.pth",  # Finale
        ]
        
        # Aggiungi checkpoint per epoca se esistono
        s2_candidates.extend(glob.glob("results/checkpoints/stage2/generator_s2_epoch_*.pth"))
        
        for path in s2_candidates:
            if os.path.exists(path):
                best_s2_path = path
                break
        
        # ===== COPIA I CHECKPOINT =====
        copied = []
        
        # Stage-I
        if best_s1_path:
            dest_s1 = f"{hf_checkpoint_dir}/generator_s1.pth"
            shutil.copy2(best_s1_path, dest_s1)
            size_mb = os.path.getsize(dest_s1) / (1024 * 1024)
            print(f"✅ Stage-I copiato:")
            print(f"   Origine: {best_s1_path}")
            print(f"   Destinazione: {dest_s1}")
            print(f"   Dimensione: {size_mb:.1f} MB")
            copied.append("Stage-I")
        else:
            print("❌ Nessun checkpoint Stage-I trovato!")
            print("   Assicurati di aver eseguito il training Stage-I")
        
        print()
        
        # Stage-II
        if best_s2_path:
            dest_s2 = f"{hf_checkpoint_dir}/stage2/generator_s2.pth"
            shutil.copy2(best_s2_path, dest_s2)
            size_mb = os.path.getsize(dest_s2) / (1024 * 1024)
            print(f"✅ Stage-II copiato:")
            print(f"   Origine: {best_s2_path}")
            print(f"   Destinazione: {dest_s2}")
            print(f"   Dimensione: {size_mb:.1f} MB")
            copied.append("Stage-II")
        else:
            print("❌ Nessun checkpoint Stage-II trovato!")
            print("   Assicurati di aver eseguito il training Stage-II")
        
        print()
        
        # ===== VERIFICA STRUTTURA FINALE =====
        print("📋 STRUTTURA FINALE per Hugging Face:")
        print("huggingface_deploy/")
        print("├── app.py                    # ✅ App Gradio")
        print("├── requirements.txt          # ✅ Dipendenze")
        print("├── checkpoints/              # 🎯 CHECKPOINT")
        
        if os.path.exists(f"{hf_checkpoint_dir}/generator_s1.pth"):
            size_s1 = os.path.getsize(f"{hf_checkpoint_dir}/generator_s1.pth") / (1024 * 1024)
            print(f"│   ├── generator_s1.pth      # ✅ {size_s1:.1f} MB")
        else:
            print(f"│   ├── generator_s1.pth      # ❌ MANCANTE")
            
        print(f"│   └── stage2/")
        
        if os.path.exists(f"{hf_checkpoint_dir}/stage2/generator_s2.pth"):
            size_s2 = os.path.getsize(f"{hf_checkpoint_dir}/stage2/generator_s2.pth") / (1024 * 1024)
            print(f"│       └── generator_s2.pth  # ✅ {size_s2:.1f} MB")
        else:
            print(f"│       └── generator_s2.pth  # ❌ MANCANTE")
        
        print()
        
        # ===== ISTRUZIONI FINALI =====
        if copied:
            print("🎉 PREPARAZIONE COMPLETATA!")
            print(f"✅ Checkpoint copiati: {', '.join(copied)}")
            print()
            print("📋 PROSSIMI PASSI:")
            print("1. 📁 La cartella huggingface_deploy/ è pronta")
            print("2. 🌐 Vai su https://huggingface.co/spaces/Biobay88/deep")
            print("3. 📤 Files → Upload files")
            print("4. 📁 Carica TUTTA la cartella huggingface_deploy/")
            print("5. ⏰ Aspetta il build (2-3 minuti)")
            print("6. 🎮 Testa la demo con Pokemon realistici!")
            print()
            print("💡 IMPORTANTE: L'app.py ora cerca i checkpoint in 'checkpoints/'")
            print("   Quindi basta caricare la cartella e tutto funziona!")
        else:
            print("❌ NESSUN CHECKPOINT PREPARATO!")
            print("Esegui prima il training dei modelli.")
        
        return len(copied) > 0
        
    except Exception as e:
        print(f"❌ Errore preparazione: {e}")
        return False

# Esegui preparazione
success = prepare_checkpoints_for_hf()

if success:
    print("\n🚀 TUTTO PRONTO PER IL DEPLOY!")
    print("Ora puoi caricare la cartella huggingface_deploy/ su Hugging Face Spaces")
else:
    print("\n⚠️ Preparazione fallita - controlla i checkpoint")

# %% [markdown]
# # 🔧 **TEST LOCALE PRIMA DEL DEPLOY**
#
# ## 🎯 **Prima di caricare su Hugging Face, testiamo tutto localmente!**
#
# ### **PASSO 1: Prepara i checkpoint** ⬆️
# **Esegui la cella sopra** per copiare i checkpoint con la struttura corretta
#
# ### **PASSO 2: Test locale** ⬇️
# **Esegui la cella sotto** per testare l'app Gradio in locale
#
# ### **PASSO 3: Verifica funzionamento** 🎮
# - ✅ **Stage-I caricato** correttamente?
# - ✅ **Stage-II caricato** correttamente?
# - ✅ **Pokemon realistici** generati?
# - ✅ **Interfaccia** funziona bene?
#
# ### **PASSO 4: Deploy su HF** 🚀
# **Solo se tutto funziona** in locale, carichi su Hugging Face
#
# ---
#
# ## 💡 **Vantaggi del test locale:**
# - 🔍 **Debug facile** - vedi errori subito
# - ⚡ **Test veloce** - niente attesa build
# - 🎯 **Verifica checkpoint** - confermi che sono buoni
# - 🛠️ **Fix immediato** - correggi problemi al volo

# %%
# 🔧 TEST LOCALE dell'App Hugging Face
print("🔧 Test locale della demo Hugging Face")
print("=" * 45)

import sys
import os
import subprocess

# Aggiungi il percorso corretto per import
if 'huggingface_deploy' not in sys.path:
    sys.path.insert(0, 'huggingface_deploy')
    print("✅ Path huggingface_deploy aggiunto")

# Cambia directory di lavoro per i percorsi relativi
original_dir = os.getcwd()
os.chdir('huggingface_deploy')
print(f"✅ Directory cambiata in: {os.getcwd()}")

try:
    # Test import dell'app
    print("\n📦 Test import moduli...")
    
    # Installa gradio se necessario
    try:
        import gradio as gr
        print("✅ Gradio già disponibile")
    except ImportError:
        print("📦 Installazione Gradio...")
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'gradio'])
        import gradio as gr
        print("✅ Gradio installato!")
    
    # Importa l'app
    print("📂 Import dell'app...")
    
    # Import base
    import torch
    import numpy as np
    from PIL import Image
    print("✅ Import base OK")
    
    # Import modelli StackGAN
    try:
        from src.models.encoder import TextEncoder
        from src.models.decoder import GeneratorS1, GeneratorS2
        import src.config as config
        print("✅ Modelli StackGAN importati")
    except ImportError as e:
        print(f"❌ Errore import modelli: {e}")
        print("💡 Assicurati che la cartella src/ sia presente")
        raise
    
    print("\n🚀 Inizializzazione app...")
    
    # Classe dell'app (copiata da app.py)
    class StackGANLocalTest:
        def __init__(self):
            self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
            print(f"🚀 Device: {self.device}")
            
            if not torch.cuda.is_available():
                print("⚠️ CUDA non disponibile - usando CPU (più lento)")
            
            try:
                # Inizializza modelli
                print("📦 Inizializzazione modelli...")
                self.text_encoder = TextEncoder(model_name=config.ENCODER_MODEL_NAME, fine_tune=False).to(self.device)
                self.generator_s1 = GeneratorS1(config=config).to(self.device)
                self.generator_s2 = GeneratorS2(config=config).to(self.device)
                print("✅ Modelli inizializzati")
                
                # Carica checkpoint
                self._load_checkpoints()
                
                # Eval mode
                self.text_encoder.eval()
                self.generator_s1.eval()
                self.generator_s2.eval()
                
                self.ready = True
                print("✅ App pronta per test!")
                
            except Exception as e:
                print(f"❌ Errore inizializzazione: {e}")
                self.ready = False
                raise
        
        def _load_checkpoints(self):
            """Carica checkpoint con percorsi corretti"""
            self.s1_loaded = False
            self.s2_loaded = False
            
            print("\n🔍 Test caricamento checkpoint...")
            
            # Stage-I
            s1_path = "checkpoints/generator_s1.pth"
            print(f"🎯 Cercando Stage-I: {s1_path}")
            
            if os.path.exists(s1_path):
                try:
                    self.generator_s1.load_state_dict(torch.load(s1_path, map_location=self.device))
                    self.s1_loaded = True
                    size_mb = os.path.getsize(s1_path) / (1024 * 1024)
                    print(f"✅ Stage-I caricato! ({size_mb:.1f} MB)")
                except Exception as e:
                    print(f"❌ Errore Stage-I: {e}")
            else:
                print(f"❌ Stage-I non trovato in: {s1_path}")
                print("💡 Esegui prima la cella di preparazione checkpoint")
            
            # Stage-II
            s2_path = "checkpoints/stage2/generator_s2.pth"
            print(f"🚀 Cercando Stage-II: {s2_path}")
            
            if os.path.exists(s2_path):
                try:
                    self.generator_s2.load_state_dict(torch.load(s2_path, map_location=self.device))
                    self.s2_loaded = True
                    size_mb = os.path.getsize(s2_path) / (1024 * 1024)
                    print(f"✅ Stage-II caricato! ({size_mb:.1f} MB)")
                except Exception as e:
                    print(f"⚠️ Stage-II parziale: {e}")
                    try:
                        self.generator_s2.load_state_dict(torch.load(s2_path, map_location=self.device), strict=False)
                        self.s2_loaded = True
                        print("✅ Stage-II caricato (parziale)")
                    except:
                        print("❌ Stage-II fallito completamente")
            else:
                print(f"❌ Stage-II non trovato in: {s2_path}")
                print("💡 Esegui prima la cella di preparazione checkpoint")
            
            # Summary
            print(f"\n📊 RISULTATO CARICAMENTO:")
            print(f"   🎯 Stage-I: {'✅ OK' if self.s1_loaded else '❌ FAIL'}")
            print(f"   🚀 Stage-II: {'✅ OK' if self.s2_loaded else '❌ FAIL'}")
        
        def test_generation(self, prompt="a red fire dragon pokemon"):
            """Test di generazione"""
            if not self.ready:
                return "❌ App non pronta"
            
            print(f"\n🎮 TEST GENERAZIONE: '{prompt}'")
            
            try:
                with torch.no_grad():
                    # Tokenizza
                    from transformers import AutoTokenizer
                    tokenizer = AutoTokenizer.from_pretrained(config.ENCODER_MODEL_NAME)
                    
                    tokens = tokenizer(prompt, padding='max_length', 
                                     max_length=config.MAX_TEXT_LENGTH, 
                                     truncation=True, return_tensors='pt')
                    
                    input_ids = tokens['input_ids'].to(self.device)
                    attention_mask = tokens['attention_mask'].to(self.device)
                    
                    # Encode text
                    cls_embedding, hidden_states = self.text_encoder(input_ids, attention_mask)
                    print(f"✅ Testo codificato: {cls_embedding.shape}")
                    
                    # Stage-I
                    if self.s1_loaded:
                        noise = torch.randn(1, config.Z_DIM, device=self.device)
                        stage1_img, stage1_mu = self.generator_s1(cls_embedding, hidden_states, noise)
                        print(f"✅ Stage-I generato: {stage1_img.shape}")
                        stage1_success = True
                    else:
                        print("⚠️ Stage-I non caricato - test fallito")
                        return "❌ Stage-I non disponibile"
                    
                    # Stage-II
                    if self.s2_loaded:
                        try:
                            stage2_img, _ = self.generator_s2(stage1_img, cls_embedding, stage1_mu)
                            print(f"✅ Stage-II generato: {stage2_img.shape}")
                            stage2_success = True
                        except Exception as e:
                            print(f"⚠️ Stage-II fallito: {str(e)[:50]}...")
                            stage2_success = False
                    else:
                        print("⚠️ Stage-II non caricato")
                        stage2_success = False
                    
                    # Risultato
                    if stage1_success and stage2_success:
                        result = "🎉 PERFETTO! Entrambi gli stage funzionano!"
                    elif stage1_success:
                        result = "✅ Stage-I OK, Stage-II con problemi (ma usabile)"
                    else:
                        result = "❌ Problemi gravi - controlla checkpoint"
                    
                    print(f"\n{result}")
                    return result
                    
            except Exception as e:
                error = f"❌ Errore generazione: {str(e)}"
                print(error)
                return error
    
    # Inizializza e testa
    print("=" * 50)
    app_test = StackGANLocalTest()
    
    if app_test.ready:
        # Test di generazione
        result = app_test.test_generation()
        
        print("\n" + "=" * 50)
        print("🏁 RISULTATO TEST LOCALE:")
        print(result)
        
        if "PERFETTO" in result or "Stage-I OK" in result:
            print("\n🚀 PRONTO PER DEPLOY!")
            print("✅ I checkpoint funzionano")
            print("✅ L'app è configurata bene")
            print("✅ Puoi caricare su Hugging Face Spaces")
            
            # Avvia demo locale per test completo
            print("\n💡 Vuoi testare l'interfaccia Gradio? Decommentare sotto:")
            print("# demo_app.launch(share=False, debug=True)")
        else:
            print("\n⚠️ PROBLEMI RILEVATI!")
            print("❌ Risolvi i problemi prima del deploy")
            print("💡 Controlla che i checkpoint siano stati preparati correttamente")
    
    else:
        print("\n❌ TEST FALLITO!")
        print("App non inizializzata correttamente")

except Exception as e:
    print(f"\n❌ ERRORE CRITICO: {e}")
    import traceback
    traceback.print_exc()

finally:
    # Ripristina directory originale
    os.chdir(original_dir)
    print(f"\n🔄 Directory ripristinata: {os.getcwd()}")

print("\n" + "=" * 50)
print("🔍 TEST LOCALE COMPLETATO!")
print("Se tutto OK, procedi con il deploy su Hugging Face")
print("=" * 50)

# %%
# 🌐 DEMO GRADIO LOCALE (Test Interfaccia Completa)
print("🌐 Avvio demo Gradio locale per test completo")
print("=" * 50)

# Solo se il test precedente è andato bene
try:
    if 'app_test' in locals() and app_test.ready:
        print("✅ App test pronta - avvio interfaccia Gradio")
        
        import gradio as gr
        
        def generate_local_test(text_prompt, seed=42):
            """Funzione di generazione per test locale"""
            if not text_prompt.strip():
                return None, None, "⚠️ Inserisci una descrizione!"
            
            try:
                # Imposta seed
                torch.manual_seed(seed)
                np.random.seed(seed)
                if torch.cuda.is_available():
                    torch.cuda.manual_seed(seed)
                
                print(f"🎯 Generando: '{text_prompt[:30]}...'")
                
                with torch.no_grad():
                    # Tokenizza
                    from transformers import AutoTokenizer
                    tokenizer = AutoTokenizer.from_pretrained(config.ENCODER_MODEL_NAME)
                    
                    tokens = tokenizer(text_prompt, padding='max_length', 
                                     max_length=config.MAX_TEXT_LENGTH, 
                                     truncation=True, return_tensors='pt')
                    
                    input_ids = tokens['input_ids'].to(app_test.device)
                    attention_mask = tokens['attention_mask'].to(app_test.device)
                    
                    # Encode text
                    cls_embedding, hidden_states = app_test.text_encoder(input_ids, attention_mask)
                    
                    # Stage-I
                    noise = torch.randn(1, config.Z_DIM, device=app_test.device)
                    stage1_img, stage1_mu = app_test.generator_s1(cls_embedding, hidden_states, noise)
                    
                    # Stage-II
                    stage2_success = False
                    if app_test.s2_loaded:
                        try:
                            stage2_img, _ = app_test.generator_s2(stage1_img, cls_embedding, stage1_mu)
                            stage2_success = True
                        except Exception as e:
                            print(f"⚠️ Stage-II fallback: {str(e)[:30]}...")
                            import torch.nn.functional as F
                            stage2_img = F.interpolate(stage1_img, size=(215, 215), mode='bilinear')
                    else:
                        import torch.nn.functional as F
                        stage2_img = F.interpolate(stage1_img, size=(215, 215), mode='bilinear')
                    
                    # Converti in PIL
                    def tensor_to_pil(tensor):
                        tensor = (tensor + 1.0) / 2.0
                        tensor = torch.clamp(tensor, 0, 1)
                        np_img = tensor.cpu().numpy().transpose(1, 2, 0)
                        np_img = (np_img * 255).astype(np.uint8)
                        return Image.fromarray(np_img, 'RGB')
                    
                    stage1_pil = tensor_to_pil(stage1_img[0])
                    stage2_pil = tensor_to_pil(stage2_img[0])
                    
                    # Info
                    info = f"""✅ Pokemon generato localmente!
📝 Prompt: '{text_prompt}'
🎲 Seed: {seed}
🚀 Device: {app_test.device}

🔧 Status:
• Stage-I: {'✅ Caricato' if app_test.s1_loaded else '❌ Non caricato'}
• Stage-II: {'✅ Caricato' if app_test.s2_loaded and stage2_success else '⚠️ Fallback' if app_test.s2_loaded else '❌ Non caricato'}

💡 Se funziona qui, funzionerà anche su Hugging Face!"""
                    
                    print("🎉 Generazione completata!")
                    return stage1_pil, stage2_pil, info
                    
            except Exception as e:
                error_info = f"""❌ Errore durante la generazione:
{str(e)}

🔧 Debug:
• Controlla che i checkpoint siano caricati
• Verifica che il testo non sia vuoto
• Assicurati che i modelli siano in eval mode"""
                return None, None, error_info
        
        # Interfaccia Gradio per test locale
        with gr.Blocks(title="🔧 StackGAN Local Test", theme=gr.themes.Soft()) as demo_local:
            
            gr.Markdown(f"""
            # 🔧 StackGAN Pokemon Generator - TEST LOCALE
            
            **Test della configurazione prima del deploy su Hugging Face**
            
            **Status Test:**
            - 🎯 Stage-I: {'✅ Caricato' if app_test.s1_loaded else '❌ Non caricato'}
            - 🚀 Stage-II: {'✅ Caricato' if app_test.s2_loaded else '❌ Non caricato'}
            - 🖥️ Device: {app_test.device}
            
            **💡 Se tutto funziona qui, puoi procedere con il deploy!**
            """)
            
            with gr.Row():
                with gr.Column(scale=1):
                    text_input = gr.Textbox(
                        label="📝 Descrizione Pokemon",
                        placeholder="Scrivi la descrizione del Pokemon...",
                        lines=3,
                        value="a red fire dragon pokemon with wings"
                    )
                    
                    seed_input = gr.Slider(
                        minimum=1,
                        maximum=1000,
                        value=42,
                        step=1,
                        label="🎲 Seed"
                    )
                    
                    generate_btn = gr.Button(
                        "🔧 Test Generazione Locale!",
                        variant="primary",
                        size="lg"
                    )
                
                with gr.Column(scale=2):
                    with gr.Row():
                        stage1_output = gr.Image(
                            label="🎯 Stage-I (64x64)",
                            height=250
                        )
                        stage2_output = gr.Image(
                            label="🚀 Stage-II (215x215)",
                            height=250
                        )
                    
                    info_output = gr.Markdown(
                        "👆 Clicca 'Test Generazione Locale' per verificare che tutto funzioni!"
                    )
            
            # Collega evento
            generate_btn.click(
                fn=generate_local_test,
                inputs=[text_input, seed_input],
                outputs=[stage1_output, stage2_output, info_output]
            )
            
            # Esempi di test
            gr.Examples(
                examples=[
                    ["a red fire dragon pokemon with wings", 42],
                    ["a blue water pokemon with fins", 123],
                    ["a yellow electric mouse pokemon", 456],
                    ["a green grass pokemon with leaves", 789]
                ],
                inputs=[text_input, seed_input],
                label="🎯 Test con questi esempi!"
            )
        
        print("✅ Interfaccia Gradio locale creata!")
        print("🚀 Avvio demo...")
        
        # Avvia demo locale
        try:
            demo_local.launch(
                share=False,  # Solo locale
                debug=True,
                show_error=True,
                server_name="127.0.0.1",
                server_port=7860,
                quiet=False
            )
        except Exception as e:
            print(f"⚠️ Errore avvio demo: {e}")
            print("💡 Prova con una porta diversa...")
            try:
                demo_local.launch(
                    share=False,
                    server_port=7861,
                    debug=True
                )
            except Exception as e2:
                print(f"❌ Errore critico demo: {e2}")
        
    else:
        print("❌ App test non pronta!")
        print("💡 Esegui prima la cella di test precedente e assicurati che funzioni")
        
except Exception as e:
    print(f"❌ Errore demo locale: {e}")
    print("💡 Controlla che Gradio sia installato e i modelli siano caricati")

print("\n🎯 ISTRUZIONI TEST LOCALE:")
print("1. ✅ Se la demo si avvia senza errori")
print("2. 🎮 Testa la generazione con gli esempi")
print("3. 🔍 Verifica che le immagini siano realistiche")
print("4. 🚀 Se tutto OK, procedi con il deploy HF!")
print("5. ❌ Se ci sono errori, debugga prima del deploy")

# %% [markdown]
# # 🎮 **DEMO GRADIO LOCALE SEMPLICE**
#
# ## 🎯 **Quello che serve:**
#
# 1. **I tuoi checkpoint allenati** in:
#    ```
#    results/checkpoints/generator_s1.pth
#    results/checkpoints/stage2/generator_s2.pth
#    ```
#
# 2. **Eseguire la cella sotto** che:
#    - ✅ Carica i checkpoint automaticamente
#    - ✅ Avvia demo Gradio in locale
#    - ✅ Ti dà l'URL per accedere
#
# ## 🚀 **Risultato:**
# - 🌐 **Demo locale** su `http://localhost:7860`
# - 🎮 **Interfaccia completa** per generare Pokemon
# - 🔥 **Pokemon realistici** dai tuoi modelli allenati
#
# ## 💡 **Niente Hugging Face, tutto locale!**

# %%
# 🎮 DEMO GRADIO LOCALE - VERSIONE SEMPLICE
print("🎮 Avvio demo StackGAN Gradio locale")
print("=" * 45)

import os
import torch
import numpy as np
from PIL import Image
import subprocess
import sys

# Installa Gradio se necessario
try:
    import gradio as gr
    print("✅ Gradio disponibile")
except ImportError:
    print("📦 Installazione Gradio...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "gradio"])
    import gradio as gr
    print("✅ Gradio installato!")

# Import modelli StackGAN
try:
    from src.models.encoder import TextEncoder
    from src.models.decoder import GeneratorS1, GeneratorS2
    import src.config as config
    print("✅ Modelli StackGAN importati")
except ImportError as e:
    print(f"❌ Errore import: {e}")
    print("💡 Assicurati di aver eseguito il setup iniziale")
    raise

class StackGANDemo:
    def __init__(self):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        print(f"🚀 Inizializzazione su: {self.device}")
        
        # Inizializza modelli
        print("📦 Caricamento modelli...")
        self.text_encoder = TextEncoder(model_name=config.ENCODER_MODEL_NAME, fine_tune=False).to(self.device)
        self.generator_s1 = GeneratorS1(config=config).to(self.device)
        self.generator_s2 = GeneratorS2(config=config).to(self.device)
        print("✅ Modelli inizializzati!")
        
        # Carica checkpoint dai percorsi standard
        self._load_checkpoints()
        
        # Modalità evaluation
        self.text_encoder.eval()
        self.generator_s1.eval()
        self.generator_s2.eval()
        
        print("🎉 Demo pronta!")
    
    def _load_checkpoints(self):
        """Carica i checkpoint dai percorsi standard del training"""
        print("🔍 Caricamento checkpoint...")
        
        # Percorsi standard dove il training salva i checkpoint
        s1_path = "results/checkpoints/generator_s1.pth"
        s2_path = "results/checkpoints/stage2/generator_s2.pth"
        
        # Stage-I
        if os.path.exists(s1_path):
            try:
                self.generator_s1.load_state_dict(torch.load(s1_path, map_location=self.device))
                size_mb = os.path.getsize(s1_path) / (1024 * 1024)
                print(f"✅ Stage-I caricato: {s1_path} ({size_mb:.1f} MB)")
                self.s1_loaded = True
            except Exception as e:
                print(f"❌ Errore Stage-I: {e}")
                self.s1_loaded = False
        else:
            print(f"❌ Stage-I non trovato in: {s1_path}")
            print("💡 Esegui prima il training Stage-I")
            self.s1_loaded = False
        
        # Stage-II
        if os.path.exists(s2_path):
            try:
                self.generator_s2.load_state_dict(torch.load(s2_path, map_location=self.device))
                size_mb = os.path.getsize(s2_path) / (1024 * 1024)
                print(f"✅ Stage-II caricato: {s2_path} ({size_mb:.1f} MB)")
                self.s2_loaded = True
            except Exception as e:
                print(f"⚠️ Stage-II parziale: {e}")
                try:
                    # Prova caricamento parziale
                    checkpoint = torch.load(s2_path, map_location=self.device)
                    self.generator_s2.load_state_dict(checkpoint, strict=False)
                    print("✅ Stage-II caricato (parziale)")
                    self.s2_loaded = True
                except Exception as e2:
                    print(f"❌ Stage-II fallito: {e2}")
                    self.s2_loaded = False
        else:
            print(f"❌ Stage-II non trovato in: {s2_path}")
            print("💡 Esegui prima il training Stage-II")
            self.s2_loaded = False
        
        # Riepilogo
        print(f"\n📊 Status caricamento:")
        print(f"   🎯 Stage-I (64x64): {'✅ OK' if self.s1_loaded else '❌ MANCANTE'}")
        print(f"   🚀 Stage-II (215x215): {'✅ OK' if self.s2_loaded else '❌ MANCANTE'}")
        
        if not self.s1_loaded:
            print("\n⚠️ ATTENZIONE: Senza Stage-I la demo non funzionerà!")
            print("Esegui il training prima di avviare la demo")
    
    def generate_pokemon(self, text_prompt, seed=42):
        """Genera Pokemon dal testo"""
        if not text_prompt.strip():
            return None, None, "⚠️ Inserisci una descrizione del Pokemon!"
        
        if not self.s1_loaded:
            return None, None, "❌ Stage-I non caricato! Esegui prima il training."
        
        try:
            # Imposta seed per riproducibilità
            torch.manual_seed(seed)
            np.random.seed(seed)
            if torch.cuda.is_available():
                torch.cuda.manual_seed(seed)
            
            print(f"🎯 Generando: '{text_prompt[:40]}...'")
            
            with torch.no_grad():
                # Codifica testo
                from transformers import AutoTokenizer
                tokenizer = AutoTokenizer.from_pretrained(config.ENCODER_MODEL_NAME)
                
                tokens = tokenizer(text_prompt, padding='max_length', 
                                 max_length=config.MAX_TEXT_LENGTH, 
                                 truncation=True, return_tensors='pt')
                
                input_ids = tokens['input_ids'].to(self.device)
                attention_mask = tokens['attention_mask'].to(self.device)
                
                # Encode text
                cls_embedding, hidden_states = self.text_encoder(input_ids, attention_mask)
                
                # Stage-I: genera 64x64
                noise = torch.randn(1, config.Z_DIM, device=self.device)
                stage1_img, stage1_mu = self.generator_s1(cls_embedding, hidden_states, noise)
                
                # Stage-II: genera 215x215
                stage2_success = False
                if self.s2_loaded:
                    try:
                        stage2_img, _ = self.generator_s2(stage1_img, cls_embedding, stage1_mu)
                        stage2_success = True
                    except Exception as e:
                        print(f"⚠️ Stage-II fallito: {str(e)[:50]}...")
                        # Fallback: ridimensiona Stage-I
                        import torch.nn.functional as F
                        stage2_img = F.interpolate(stage1_img, size=(215, 215), mode='bilinear', align_corners=False)
                else:
                    # Solo Stage-I disponibile
                    import torch.nn.functional as F
                    stage2_img = F.interpolate(stage1_img, size=(215, 215), mode='bilinear', align_corners=False)
                
                # Converti tensori in immagini PIL
                def tensor_to_pil(tensor):
                    tensor = (tensor + 1.0) / 2.0  # Da [-1,1] a [0,1]
                    tensor = torch.clamp(tensor, 0, 1)
                    np_img = tensor.cpu().numpy().transpose(1, 2, 0)
                    np_img = (np_img * 255).astype(np.uint8)
                    return Image.fromarray(np_img, 'RGB')
                
                stage1_pil = tensor_to_pil(stage1_img[0])
                stage2_pil = tensor_to_pil(stage2_img[0])
                
                # Info dettagliata
                status_info = []
                if self.s1_loaded:
                    status_info.append("✅ Stage-I: Modello allenato (64x64)")
                else:
                    status_info.append("❌ Stage-I: Non disponibile")
                
                if self.s2_loaded and stage2_success:
                    status_info.append("✅ Stage-II: Modello allenato (215x215)")
                elif self.s2_loaded:
                    status_info.append("⚠️ Stage-II: Modalità compatibilità")
                else:
                    status_info.append("⚠️ Stage-II: Ridimensionamento Stage-I")
                
                info = f"""🎉 Pokemon generato con successo!
                
📝 **Prompt:** "{text_prompt}"
🎲 **Seed:** {seed}
🖥️ **Device:** {self.device}

🔧 **Status Modelli:**
{chr(10).join(status_info)}

💡 **Suggerimenti:**
- Descrizioni dettagliate danno risultati migliori
- Prova seed diversi per variazioni
- Stage-II migliora la qualità dell'immagine
"""
                
                print("🎉 Generazione completata!")
                return stage1_pil, stage2_pil, info
        
        except Exception as e:
            error_msg = f"""❌ Errore durante la generazione:
{str(e)}

🔧 **Debug:**
- Verifica che i checkpoint siano caricati
- Controlla che il testo non sia vuoto
- Assicurati di aver fatto il training prima"""
            
            print(f"❌ Errore: {e}")
            return None, None, error_msg

# Inizializza la demo
print("🚀 Inizializzazione demo...")
try:
    demo = StackGANDemo()
    demo_ready = True
    print("✅ Demo inizializzata con successo!")
except Exception as e:
    print(f"❌ Errore inizializzazione: {e}")
    demo_ready = False

# Crea interfaccia Gradio
if demo_ready:
    print("🌐 Creazione interfaccia Gradio...")
    
    with gr.Blocks(
        title="🎮 StackGAN Pokemon Generator",
        theme=gr.themes.Soft(),
        css=".gradio-container {max-width: 1200px !important}"
    ) as app:
        
        gr.Markdown(f"""
        # 🎮 StackGAN Pokemon Generator - Demo Locale
        
        **Genera Pokemon unici dalle tue descrizioni testuali!**
        
        **🔧 Status Sistema:**
        - 🎯 Stage-I (64x64): {'✅ Attivo' if demo.s1_loaded else '❌ Non disponibile'}
        - 🚀 Stage-II (215x215): {'✅ Attivo' if demo.s2_loaded else '❌ Non disponibile'}
        - 🖥️ Device: {demo.device}
        
        **💡 Come usare:**
        1. Scrivi una descrizione dettagliata del Pokemon
        2. Scegli un seed per riproducibilità (opzionale)
        3. Clicca "Genera Pokemon!"
        4. Ammira il tuo Pokemon personalizzato!
        """)
        
        with gr.Row():
            with gr.Column(scale=1):
                text_input = gr.Textbox(
                    label="📝 Descrizione Pokemon",
                    placeholder="Es: a red fire dragon pokemon with wings and a long tail",
                    lines=4,
                    value="a red fire dragon pokemon with wings and a long tail"
                )
                
                seed_input = gr.Slider(
                    minimum=1,
                    maximum=10000,
                    value=42,
                    step=1,
                    label="🎲 Seed (per riproducibilità)"
                )
                
                generate_btn = gr.Button(
                    "🎮 Genera Pokemon!",
                    variant="primary",
                    size="lg",
                    scale=2
                )
                
                gr.Markdown("""
                **💡 Consigli per migliori risultati:**
                - Descrivi colore, tipo, caratteristiche fisiche
                - Usa termini Pokemon: "fire type", "water pokemon", etc.
                - Più dettagli = risultati migliori
                """)
            
            with gr.Column(scale=2):
                with gr.Row():
                    stage1_output = gr.Image(
                        label="🎯 Stage-I Output (64x64)",
                        height=300,
                        show_label=True
                    )
                    stage2_output = gr.Image(
                        label="🚀 Stage-II Output (215x215)",
                        height=300,
                        show_label=True
                    )
                
                info_output = gr.Markdown(
                    "👆 **Inserisci una descrizione e clicca 'Genera Pokemon!' per iniziare!**",
                    elem_classes="info-box"
                )
        
        # Esempi predefiniti
        gr.Examples(
            examples=[
                ["a red fire dragon pokemon with wings and a long tail", 42],
                ["a blue water pokemon with fins and bubbles around it", 123],
                ["a yellow electric mouse pokemon with lightning bolts", 456],
                ["a green grass pokemon with leaves and flowers", 789],
                ["a purple psychic cat pokemon with mystical aura", 101],
                ["a brown ground type pokemon with armor-like skin", 555],
                ["a white ice pokemon with crystal formations", 888],
                ["a black dark type pokemon with glowing red eyes", 999]
            ],
            inputs=[text_input, seed_input],
            label="🎯 Esempi rapidi - Clicca per testare!"
        )
        
        # Collega l'evento di generazione
        generate_btn.click(
            fn=demo.generate_pokemon,
            inputs=[text_input, seed_input],
            outputs=[stage1_output, stage2_output, info_output],
            show_progress=True
        )
    
    print("✅ Interfaccia creata!")
    
    # Avvia la demo
    print("\n🚀 Avvio demo Gradio...")
    print("=" * 45)
    
    try:
        app.launch(
            server_name="0.0.0.0",  # Accessibile da tutta la rete locale
            server_port=7860,
            share=False,  # Solo locale, no link pubblico
            debug=True,
            show_error=True,
            inbrowser=True,  # Apre automaticamente il browser
            quiet=False
        )
        
    except Exception as e:
        print(f"⚠️ Porta 7860 occupata, provo 7861...")
        try:
            app.launch(
                server_port=7861,
                share=False,
                debug=True,
                inbrowser=True
            )
        except Exception as e2:
            print(f"❌ Errore avvio demo: {e2}")
            print("💡 Prova a riavviare il notebook")

else:
    print("❌ Demo non inizializzata!")
    print("💡 Controlla che i checkpoint siano presenti e il training sia completato")

print("\n🎉 DEMO AVVIATA!")
print("🌐 Accedi alla demo da:")
print("   • Computer locale: http://localhost:7860")
print("   • Altri dispositivi rete: http://[TUO-IP]:7860")
print("🎮 Buon divertimento con i tuoi Pokemon!")
print("=" * 50)
